# %% [markdown]
# <a href="https://colab.research.google.com/github/RealGIS-creator/scripts_realgis_banistmo_2025/blob/main/GEOCOD_GOOGLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googlemaps pandas openpyxl

import googlemaps
import pandas as pd

gmaps = googlemaps.Client(key="AIzaSyB7fIVen3_P5jRpaA_7tlHf_GTAM5QpYRA")

def geocode_addresses(excel_file_path):

    try:
        df = pd.read_excel(excel_file_path)
        if 'direccion_residencial' not in df.columns:
            raise ValueError("La columna 'direccion_residencial' no se encuentra en el archivo Excel.")
        geocoded_data = []
        for index, row in df.iterrows():
            address = row['direccion_residencial']
            try:
                geocode_result = gmaps.geocode(address)

                if geocode_result:
                    latitude = geocode_result[0]['geometry']['location']['lat']
                    longitude = geocode_result[0]['geometry']['location']['lng']
                    geocoded_data.append({'direccion': address, 'latitud': latitude, 'longitud': longitude, 'estado': 'Éxito'})
                else:
                    geocoded_data.append({'direccion': address, 'latitud': None, 'longitud': None, 'estado': 'No se encontró'})
            except Exception as e:
                geocoded_data.append({'direccion': address, 'latitud': None, 'longitud': None, 'estado': f'Error: {e}'})


        geocoded_df = pd.DataFrame(geocoded_data)
        return geocoded_df

    except FileNotFoundError:
        print(f"Error: Archivo '{excel_file_path}' no encontrado.")
        return None
    except Exception as e:
        print(f"Error al procesar el archivo: {e}")
        return None

file_path = '/content/Archivo_insercion.xlsx'
geocoded_results = geocode_addresses(file_path)


if geocoded_results is not None:
    print(geocoded_results)
    geocoded_results.to_excel('/content/direcciones_geocodificadas_12_mayo.xlsx', index=False)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c18eeb9827f7> in <cell line: 0>()
#      39
#      40 file_path = '/content/Archivo_insercion.xlsx'
# ---> 41 geocoded_results = geocode_addresses(file_path)
#      42
#      43
#
# <ipython-input-5-c18eeb9827f7> in geocode_addresses(excel_file_path)
#      16             address = row['direccion_residencial']
#      17             try:
# ---> 18                 geocode_result = gmaps.geocode(address)
#      19
#      20                 if geocode_result:
#
# /usr/local/lib/python3.11/dist-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     443     def wrapper(*args, **kwargs):
#     444         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 445         result = func(*args, **kwargs)
#     446         try:
#     447             del args[0]._extra_params
#
# ...

# %%
# !pip install googlemaps pandas openpyxl
import googlemaps
import pandas as pd
# !pip install googlemaps pandas openpyxl

gmaps = googlemaps.Client(key="AIzaSyDXwrPqbyUayHZ0iRJ2FVTi2O4aLezAEFY")

def geocode_addresses(excel_file_path):
    try:
        df = pd.read_excel(excel_file_path)

        if 'direccion' not in df.columns:
            raise ValueError("La columna 'direccion' no se encuentra en el archivo Excel.")
        if 'acreditado_id' not in df.columns:
            raise ValueError("La columna 'id_acreditado' no se encuentra en el archivo Excel.")
        if 'direccion_id' not in df.columns:
            raise ValueError("La columna 'id_direccion' no se encuentra en el archivo Excel.")

        geocoded_data = []

        for index, row in df.iterrows():
            acreditado_id = row['acreditado_id']
            direccion_id = row['direccion_id']
            address = row['direccion']
            try:
                geocode_result = gmaps.geocode(address)

                if geocode_result:
                    latitude = geocode_result[0]['geometry']['location']['lat']
                    longitude = geocode_result[0]['geometry']['location']['lng']
                    geocoded_data.append({'acreditado_id': acreditado_id, 'direccion_id': direccion_id, 'direccion': address, 'latitud': latitude, 'longitud': longitude, 'estado': 'Éxito'})
                else:
                    geocoded_data.append({'acreditado_id': acreditado_id,'direccion_id': direccion_id, 'direccion': address, 'latitud': None, 'longitud': None, 'estado': 'No se encontró'})
            except Exception as e:
                geocoded_data.append({'acreditado_id': acreditado_id,'direccion_id': direccion_id, 'direccion': address, 'latitud': None, 'longitud': None, 'estado': f'Error: {e}'})


        geocoded_df = pd.DataFrame(geocoded_data)
        return geocoded_df

    except FileNotFoundError:
        print(f"Error: Archivo '{excel_file_path}' no encontrado.")
        return None
    except Exception as e:
        print(f"Error al procesar el archivo: {e}")
        return None

file_path = '/content/direcciones_georreferenciadas_27052025folios.xlsx'
geocoded_results = geocode_addresses(file_path)


if geocoded_results is not None:
    print(geocoded_results)
    geocoded_results.to_excel('/content/direcciones_georreferenciadas_27052025folios.xlsx', index=False)
# Out:
# ...
#      acreditado_id  direccion_id  \
# 0            19404         54036
# 1            19493         54037
# 2            19500         54038
# 3            19504         54039
# 4            19505         54040
# ..             ...           ...
# 529          24748         54565
# 530          24762         54566
# 531          24769         54567
# 532          24772         54568
# 533          24774         54569
#
#                                              direccion   latitud   longitud  \
# 0    LOTE 112 CORREGIMIENTO SANTIAGO DISTRITO SANTI...  8.088494 -80.976056
# 1    LOTE E23 CORREGIMIENTO TOCUMEN DISTRITO PANAMA...  9.096863 -79.375242
# 2    LOTE 196B CORREGIMIENTO ARRAIJAN DISTRITO ARRA...  8.939443 -79.642349
# 3    INTERIOR 5E EDIFICIO PH COLON CENTER CORREGIMI...  9.358370 -79.901515
# 4    INTERIOR UI U12 EDIFICIO MODELO GRAN MURANO DE...  9.048518 -79.508257
# ..                                                 ...       ...        ...
# ...
